# %%
# !pip uninstall -y tensorflow
# !pip install tensorflow==2.17.1
# Out:
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 60.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Successfully uninstalled tensorboard-2.18.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.17.1 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.17.1 which is incompatible.
# ...

# %%
# !pip install torch torchvision torchaudio
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 26.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 53.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip install paddleocr paddlepaddle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 44.3 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=42c31188f0a0a848e64b3f30d8eedb3005ba0a8f7f82fe32018b4993972e56c7
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.1

# %%
import torch, detectron2
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# torch:  2.5 ; cuda:  cu124
# detectron2: 0.6

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
CHART_TYPE_DETECTION_MODEL_PATH = "/content/drive/MyDrive/Import Folder/chartTypeDetectionModel.keras"
SCATTER_PLOT_ELEMENT_DETECTION_MODEL_PATH = "/content/drive/MyDrive/Import Folder/scatter_model_weights.pth"
IMAGE_PATH = "/content/drive/MyDrive/Import Folder/image3.png"

# %% [markdown]
# # Detect Chart Type

# %%
from tensorflow.keras.saving import load_model
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array

def detectChartType(model_path, image_path, width=224, height=224):

    # Load and preprocess the image
    image = load_img(image_path, target_size=(width, height))

    # Add a batch dimension to the image
    image = np.expand_dims(image, axis=0)
    image = image.astype('float32') / 255.0  # Normalize

    # Load the model
    model = load_model(model_path)

    # Make predictions
    predictions = model(image, training=False)
    max_index = np.argmax(predictions)  # Get the index of the max score
    class_names = ["vbar_categorical", "hbar_categorical", "dot_line", "line"]

    return class_names[max_index]

# %%
chart_type = detectChartType(CHART_TYPE_DETECTION_MODEL_PATH, IMAGE_PATH)

# %%
print(chart_type)
# Out:
# dot_line

# %% [markdown]
# # Detect Chart Elements for Scatter Plots

# %%
import torch
import detectron2
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
import cv2
import matplotlib.pyplot as plt

DATASET_NAME = "scatter_plot_elements"

MetadataCatalog.get(DATASET_NAME).thing_classes = ["title", "canvas", "x-labels",
                                                   "y-labels", "x-title", "y-title",
                                                   "legend", "scale", "other text",
                                                   "quantity"]

# Load Detectron2 configuration
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.WEIGHTS = SCATTER_PLOT_ELEMENT_DETECTION_MODEL_PATH
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 10
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7
cfg.MODEL.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
import random

def detectChartElements(IMAGE_PATH):
    if detectChartType(CHART_TYPE_DETECTION_MODEL_PATH, IMAGE_PATH) != "dot_line":
        return "Not a Scatter Plot"

    # Initialize predictor
    predictor = DefaultPredictor(cfg)

    # Load the image
    image = cv2.imread(IMAGE_PATH)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Run inference
    outputs = predictor(image)

    # Extract bounding boxes, labels, and scores
    instances = outputs["instances"].to("cpu")
    boxes = instances.pred_boxes.tensor.numpy()
    labels = instances.pred_classes.numpy()
    scores = instances.scores.numpy()

    # Metadata for class names
    metadata = MetadataCatalog.get(DATASET_NAME)
    class_names = metadata.get("thing_classes", [])

    # Dictionary to store the best element per label
    detected_elements = {}
    colors = {}

    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = map(int, box)
        cropped_img = (x1, y1, x2, y2)
        label = class_names[labels[i]] if labels[i] < len(class_names) else f"class_{labels[i]}"

        # Store only the highest confidence bounding box per label
        if label not in detected_elements or scores[i] > detected_elements[label][0][1]:
            detected_elements[label] = [(cropped_img, scores[i])]
            colors[label] = [random.random(), random.random(), random.random()]

    # Visualize the final results with only the best bounding boxes
    v = Visualizer(image, metadata, scale=1.2)
    for label, box in detected_elements.items():
        x1, y1, x2, y2 = box[0][0]
        color = colors[label]
        v.draw_box([x1, y1, x2, y2], edge_color=color)
        v.draw_text(f"{label} ({box[0][1]:.2f})", [x1, y1], font_size=10, color=color)

    # Remove confidence scores from final output
    detected_elements = {label: [box[0][0]] for label, box in detected_elements.items()}

    # Display the final image
    plt.figure(figsize=(10, 10))
    plt.imshow(v.output.get_image())
    plt.axis("off")
    plt.show()

    return detected_elements

# %%
detectedElements = detectChartElements(IMAGE_PATH)
print(detectedElements)
# Out:
# /usr/local/lib/python3.11/dist-packages/fvcore/common/checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# # Text Detection in Scatter Plots

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from paddleocr import PaddleOCR, draw_ocr

# %%
import logging
# Suppress PaddleOCR logs
logging.getLogger("ppocr").setLevel(logging.ERROR)

# %%
# Initialize PaddleOCR model
ocr = PaddleOCR(use_angle_cls=True, lang="en")
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100%|██████████| 3910/3910 [00:16<00:00, 236.82it/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10000/10000 [00:19<00:00, 519.08it/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2138/2138 [00:16<00:00, 132.80it/s]

# %%
def rotate_image(image, angle):
    """Rotate image by a given angle and return the rotated image."""
    h, w = image.shape[:2]
    center = (w // 2, h // 2)

    # Get rotation matrix
    M = cv2.getRotationMatrix2D(center, angle, 1.0)

    # Compute new bounding box size
    cos = np.abs(M[0, 0])
    sin = np.abs(M[0, 1])
    new_w = int(h * sin + w * cos)
    new_h = int(h * cos + w * sin)

    # Adjust transformation matrix to move image to the center
    M[0, 2] += (new_w - w) / 2
    M[1, 2] += (new_h - h) / 2

    # Rotate the image with new bounds
    rotated = cv2.warpAffine(image, M, (new_w, new_h))

    return rotated, M

# %%
def rotate_roi(roi_x1, roi_y1, roi_x2, roi_y2, M):
  # Define the four corner points of the ROI in the original image
  roi_corners = np.array([
      [roi_x1, roi_y1],  # Top-left
      [roi_x2, roi_y1],  # Top-right
      [roi_x2, roi_y2],  # Bottom-right
      [roi_x1, roi_y2]   # Bottom-left
  ], dtype=np.float32)

  # Convert to homogeneous coordinates
  ones = np.ones((4, 1))
  roi_corners_homogeneous = np.hstack([roi_corners, ones])

  # Transform ROI coordinates using the rotation matrix M
  transformed_corners = np.dot(M, roi_corners_homogeneous.T).T

  # Get bounding box of transformed ROI
  x_min = int(min(transformed_corners[:, 0]))
  y_min = int(min(transformed_corners[:, 1]))
  x_max = int(max(transformed_corners[:, 0]))
  y_max = int(max(transformed_corners[:, 1]))

  # Ensure the new ROI is within image bounds
  x_min, y_min = max(0, x_min), max(0, y_min)
  x_max, y_max = min(image.shape[1], x_max), min(image.shape[0], y_max)

  return x_min, y_min, x_max, y_max

# %%
def inverse_transform_box(box, M):
    """Transform bounding box coordinates back to original image."""
    box = np.array(box, dtype=np.float32)
    ones = np.ones((4, 1))
    box = np.hstack([box, ones])  # Convert to homogeneous coordinates
    inv_M = cv2.invertAffineTransform(M)
    transformed_box = np.dot(inv_M, box.T).T
    return transformed_box[:, :2].astype(int)

# %%
def detect_text_in_rois(image_path, rois, width_threshold_pct=0.02, height_threshold_pct=0.1):
    # Load the image
    original = cv2.imread(image_path)
    if original is None:
        print("Error: Unable to load image.")
        return []

    best = []
    best_confidence = 0

    for angle in [0, 90, 180, 270]:
        detected_text = []  # Store (bounding_box, text)
        totalConfidence = 0
        count = 0

        for roi_x1, roi_y1, roi_x2, roi_y2 in rois:
            image = original[roi_y1:roi_y2, roi_x1:roi_x2]
            roi, M = rotate_image(image, angle)

            # Run OCR on the cropped ROI
            results = ocr.ocr(roi, cls=True)

            if results is None:
                continue

            for res in results:
                if res is None:
                    continue

                for line in res:
                    if line is None:
                        continue

                    box, (text, confidence) = line  # Get bounding box and text

                    if confidence < 0.5:
                      continue

                    # Transform bounding box back to original image coordinates
                    original_box = inverse_transform_box(box, M)

                    # Convert bounding box to global coordinates
                    adjusted_box = [
                        (int(pt[0]) + roi_x1, int(pt[1]) + roi_y1) for pt in original_box
                    ]

                    totalConfidence += confidence
                    count += 1
                    detected_text.append((adjusted_box, text))

        if count > 0:
          totalConfidence /= count

        if totalConfidence > best_confidence:
            best_confidence = totalConfidence
            best = detected_text

    for (adjusted_box, text) in best:
      # Draw bounding box and text for visualization
      cv2.polylines(original, [np.array(adjusted_box, np.int32)], isClosed=True, color=(0, 255, 0), thickness=2)
      cv2.putText(original, text, (adjusted_box[0][0], adjusted_box[0][1] - 10),
                  cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Show the image with detected text
    plt.figure(figsize=(10, 6))
    plt.imshow(cv2.cvtColor(original, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.show()

    return best  # Return list of (bounding_box, text)

# %%
labelText = {}
for label, images in detectedElements.items():
    print(label, ":")
    labelText[label] = detect_text_in_rois(IMAGE_PATH, images)
# Out:
# canvas :
# x-labels :
# title :
# legend :
# y-title :
# x-title :
# y-labels :

# %%
print(labelText)
# Out:
# {'canvas': [], 'x-labels': [([(82, 669), (82, 639), (97, 639), (97, 669)], '2003'), ([(251, 669), (251, 639), (267, 639), (267, 669)], '2006'), ([(421, 668), (421, 638), (437, 638), (437, 668)], '2007'), ([(592, 668), (592, 638), (607, 638), (607, 668)], '2008'), ([(761, 668), (761, 638), (777, 638), (777, 668)], '2009')], 'title': [([(61, 29), (61, 8), (709, 7), (709, 28)], 'Expenses (in %) made by the government on compensation of employees')], 'legend': [([(964, 685), (835, 686), (835, 673), (964, 672)], 'Trinidad and Tobago'), ([(891, 665), (833, 663), (834, 649), (892, 651)], 'Malaysia'), ([(869, 639), (833, 639), (833, 625), (869, 625)], 'Chile'), ([(1001, 618), (834, 617), (834, 602), (1001, 603)], 'East Asia (developing only)')], 'y-title': [([(21, 208), (21, 460), (6, 460), (6, 208)], 'Expenses (% of total expenses)')], 'x-title': [([(407, 693), (408, 680), (455, 680), (454, 694)], 'Years')], 'y-labels': [([(28, 73), (44, 73), (44, 90), (28, 90)], '35'), ([(28, 153), (46, 15
# ...

# %% [markdown]
# # Legend Detection

# %%
image = cv2.imread(IMAGE_PATH)

x1, y1, x2, y2 = detectedElements['legend'][0]  # Legend bounding box
legend_region = image[y1:y2, x1:x2]  # Crop legend area

# Get Image Dimensions
img_h, img_w = legend_region.shape[:2]

# Show the image with detected text
plt.figure(figsize=(10, 6))
plt.imshow(cv2.cvtColor(legend_region, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
def is_overlapping(box1, box2):
    """Check if two bounding boxes overlap and draw them using plt."""
    x1_min, y1_min, x1_max, y1_max = box1
    x2_max, y2_max, x2_min, y2_min = box2

    # Ensure min and max are correctly ordered
    x1_min, x1_max = min(x1_min, x1_max), max(x1_min, x1_max)
    y1_min, y1_max = min(y1_min, y1_max), max(y1_min, y1_max)
    x2_min, x2_max = min(x2_min, x2_max), max(x2_min, x2_max)
    y2_min, y2_max = min(y2_min, y2_max), max(y2_min, y2_max)

    return not (x1_max <= x2_min or x1_min >= x2_max or y1_max <= y2_min or y1_min >= y2_max)

# %%
# Convert to grayscale and HSV
gray = cv2.cvtColor(legend_region, cv2.COLOR_BGR2GRAY)

# Use adaptive thresholding to detect possible color blobs
thresh = cv2.adaptiveThreshold(
    gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2
)

# Find contours (detect objects)
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# Extract bounding boxes of legend text
legend_text_boxes = []

for (box, label) in labelText['legend']:
    lx1, ly1 = box[0]
    lx2, ly2 = box[2]

    new_lx1 = lx1 - x1
    new_ly1 = ly1 - y1
    new_lx2 = lx2 - x1
    new_ly2 = ly2 - y1

    legend_text_boxes.append((new_lx1, new_ly1, new_lx2, new_ly2))

# %%
# Store detected colors and positions
detected_colors = []

for cnt in contours:
    x, y, w, h = cv2.boundingRect(cnt)

    # Skip if the contour overlaps with any legend text
    if any(is_overlapping((x, y, x + w, y + h), legend_box) for legend_box in legend_text_boxes):
        continue

    # Extract color region
    color_region = legend_region[y:y+h, x:x+w]

    # Show detected color box
    plt.figure(figsize=(4, 2))
    plt.imshow(cv2.cvtColor(color_region, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.show()

    # Get average color (BGR)
    avg_color = avg_color = np.round(np.mean(color_region.reshape(-1, 3), axis=0)).astype(int)
    print("Detected Color:", avg_color)

    detected_colors.append(((x, y, x + w, y + h), avg_color))

# Sort detected shapes from left to right
detected_colors.sort()
# Out:
# Detected Color: [ 85  85 255]
# Detected Color: [235 155 128]
# Detected Color: [116 156 142]
# Detected Color: [ 85 170 170]

# %%
copy = legend_region.copy()
# Show Detected Regions
for (x1, y1, x2, y2), color in detected_colors:
    cv2.rectangle(copy, (x1, y1), (x2, y2), (0, 255, 0), 2)

for (x1, y1, x2, y2) in legend_text_boxes:
    cv2.rectangle(copy, (x1, y1), (x2, y2), (255, 0, 0), 2)

plt.figure(figsize=(10, 6))
plt.imshow(cv2.cvtColor(copy, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
from collections import defaultdict
import numpy as np

# Store assigned texts and mapped legends
mapped_legends = {}

# Convert detected shape coordinates to full image coordinates
legend_x1, legend_y1, _, _ = detectedElements['legend'][0]  # Legend bounding box

adjusted_colors = []
for (shape_box, color) in detected_colors:
    sx1, sy1, sx2, sy2 = shape_box

    # Convert shape coordinates to full image coordinates
    sx1_global = sx1 + legend_x1
    sy1_global = sy1 + legend_y1
    sx2_global = sx2 + legend_x1
    sy2_global = sy2 + legend_y1

    shape_center_x = (sx1_global + sx2_global) // 2
    shape_center_y = (sy1_global + sy2_global) // 2

    adjusted_colors.append(((shape_center_x, shape_center_y), color))

# Convert text coordinates to center points
adjusted_labels = []
for (box, label) in labelText['legend']:
    (x1, y1), (x2, _), (_, y2), (_, _) = box  # Extract text bounding box
    text_center_x = (x1 + x2) // 2  # Midpoint X
    text_center_y = (y1 + y2) // 2  # Midpoint Y
    adjusted_labels.append(((text_center_x, text_center_y), label))

# Sort colors and labels by Y to roughly group them into rows
adjusted_colors.sort(key=lambda item: item[0][1])  # Sort by Y
adjusted_labels.sort(key=lambda item: item[0][1])  # Sort by Y

# Assign labels to colors based on X proximity
def match_labels_to_colors(labels, colors, y_threshold=10):
    """
    Matches each color to the closest label horizontally (left or right).
    """
    assigned = {}

    for (color_pos, color) in colors:
        cx, cy = color_pos
        possible_labels = [lbl for lbl in labels if abs(lbl[0][1] - cy) < y_threshold]

        if not possible_labels:
            continue  # No nearby labels

        # Find the closest label in the X direction
        closest_label = min(possible_labels, key=lambda lbl: abs(lbl[0][0] - cx))
        assigned[closest_label[1]] = color
        labels.remove(closest_label)  # Remove assigned label

    return assigned

mapped_legends = match_labels_to_colors(adjusted_labels, adjusted_colors)

# %%
# Print results
for label, color in mapped_legends.items():
    print(f"Label: {label}, Color (BGR): {color}")
# Out:
# Label: East Asia (developing only), Color (BGR): [ 85 170 170]
# Label: Chile, Color (BGR): [116 156 142]
# Label: Malaysia, Color (BGR): [235 155 128]
# Label: Trinidad and Tobago, Color (BGR): [ 85  85 255]
